# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/Health_insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df['sex_enc'] = df['sex'].apply(lambda x:1 if x=='female' else 0)
df['smoker_enc'] = df['smoker'].map( {'yes': 1, 'no':0})

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'sex enc', 'smoker_enc', 'sex_enc'],
#       dtype='object')

# %%
x = df[['age' , 'sex_enc' , 'bmi' , 'children' , 'smoker_enc' ] ]
y = df['charges']

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.intercept_ , model.coef_
# Out:
# (np.float64(-12181.101839234427),
#  array([  257.73498767,   128.63985357,   322.36421449,   474.41112061,
#         23823.39253065]))

# %%
model.predict(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 model.predict(df)
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_base.py:297, in LinearModel.predict(self, X)
#     283 def predict(self, X):
#     284     """
#     285     Predict using the linear model.
#     286
#    (...)
#     295         Returns predicted values.
#     296     """
# --> 297     return self._decision_function(X)
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_base.py:276, in LinearModel._decision_function(self, X)
#     273 def _decision_function(self, X):
#     274     check_is_fitted(self)
# --> 276     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     277     coef_ = self.coef_
#     278     if coef_.ndim == 1:
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)
#    2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)
#    2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - charges
# - region
# - sex
# - sex enc
# - smoker
