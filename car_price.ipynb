# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/Used Car Dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol      5       56000
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
# 3            Dec-19      Comprehensive    Petrol      5       18378
# 4            Aug-19      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# ...

# %%
s1 = df['transmission'].apply(lambda x:x in ['Manual','Automatic'])

# %%
df.shape
# Out:
# (1553, 15)

# %%
sum(s1)
# Out:
# 1503

# %%
df[s1]
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1547        1547                         2022 Maruti Ertiga VXI CNG
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df = df[df['transmission'].isin(['Manual', 'Automatic'])]
df
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1547        1547                         2022 Maruti Ertiga VXI CNG
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df['registration_year'].apply(lambda x:int(x.split('-')[-1][-2:]))
list(df['registration_year'].value_counts().index)
# Out:
# ['Jul-18',
#  'Jul-17',
#  'Aug-18',
#  'May-17',
#  'Oct-18',
#  'Nov-18',
#  'Nov-17',
#  'Nov-19',
#  'Nov-15',
#  'Oct-17',
#  'Mar-19',
#  'Jul-16',
#  'Nov-20',
#  'Jun-18',
#  'Jul-19',
#  'Nov-21',
#  'Dec-18',
#  '2012',
#  'Aug-17',
#  'Sep-18',
#  'Mar-20',
#  'Apr-19',
#  'Oct-20',
#  'May-19',
#  'Jun-19',
#  'Oct-19',
#  'Jun-17',
#  'Apr-18',
#  'Sep-19',
#  'May-15',
#  'Sep-15',
#  'Feb-19',
#  'Aug-19',
#  'Apr-16',
#  'Oct-15',
#  'Nov-14',
#  'Feb-18',
#  'Dec-22',
#  'Aug-20',
#  'Aug-22',
#  'Jan-16',
#  'May-18',
#  'Oct-14',
#  '2017',
#  'Dec-21',
#  'Aug-16',
#  'Mar-21',
#  'Jan-20',
#  'Mar-18',
#  '2018',
#  'Dec-20',
#  'Feb-22',
#  'Jan-22',
#  '2014',
#  'Jul-21',
#  'Dec-15',
#  'Sep-16',
#  'Jul-14',
#  'Aug-21',
#  'Jun-14',
#  'Dec-17',
#  'Nov-22',
#  'Mar-16',
#  'Jan-14',
#  'Jan-21',
#  'Oct-16',
#  'Jun-15',
#  'Jul-20',
#  'Aug-15',
#  'Feb-20',
#  'Sep-17',
#  'May-22',
#  'May-16',
#  'May-14',
#  'Mar-17',
#  'Dec-16',
#  'Jul-22',
# ...
